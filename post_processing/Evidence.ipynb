# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from heatmaps import heatmap, annotate_heatmap, getLogZ, bayesPlot

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"
cmaps= ("RdYlBu","Greens")
yticklabelvisibles = (True, False)

analysisModels = ['shock','kilonova_uvboost','kilonova']
analysisLabels=['Shock','Kilonova Lower\nEarly Opacity','Kilonova Default']

dataModels = ['shock','kilonova_uvboost','kilonova']
dataLabels=['Data: Shock','Data: Kilonova\nLower Early Opacity','Data: Kilonova']

cbarlabels=["Evidence: Log$_{10}$($\mathcal{Z}$)","Bayes' factor: Log$_{10}$($\mathcal{B}$)"]

fontsize_fields = 14
fontsize_bayesplot=13

threshold_textcolor = (0.75, 0.75)

# %%
dist = 160

logz = np.asarray([[getLogZ(model,data,dist)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=160 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=160 delay=0

# %%
dist = 100

logz = np.asarray([[getLogZ(model,data,dist)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=100 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=100 delay=0

# %%
dist = 40

logz = np.asarray([[getLogZ(model,data,dist)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=0

# %%
dist = 40

logz = np.asarray([[getLogZ(model,data,dist,delay=8)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=8
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=8

# %%
dist = 40

logz = np.asarray([[getLogZ(model,data,dist,delay=12)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=12
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=12

# %%
dist = 40

logz = np.asarray([[getLogZ(model,data,dist,delay=4)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=4
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=4

# %%
dist = 40

logz = np.asarray([[getLogZ(model,data,dist,delay=2)[0] for model in analysisModels]
                   for data in dataModels])
logb = np.asarray([[np.NaN,logz[0,0]-logz[0,1],logz[0,0]-logz[0,2]],
                   [logz[1,1]-logz[1,0],np.NaN,np.NaN],
                   [logz[2,2]-logz[2,0],np.NaN,np.NaN]])
datas = (logz,logb)
norms = (colors.SymLogNorm(linthresh=10, linscale=1, 
                          vmin=-10**4,
                          vmax=10**1, base=10),
        colors.LogNorm(vmin=1,
                        vmax=10**4))

fig, axes = plt.subplots(1,2,figsize=(10,5))
for ax, data, norm, cmap, visible, cbarlabel in zip(axes, datas, norms, cmaps, yticklabelvisibles, cbarlabels):
    im, cbar = heatmap(data, dataLabels, analysisLabels, ax=ax, cmap=cmap,
                       norm=norm,
                    cbar_kw={'drawedges':False, 'pad':0.01, 'shrink':0.75},
                    cbarlabel=cbarlabel,
                    yticklabelvisible=visible)
    annotate_heatmap(im, data, threshold=threshold_textcolor, valfmt="{x:.1f}", fontsize=fontsize_fields)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/heatmap_{dist}Mpc.png',dpi=300,pad_inches=0.3,bbox_inches='tight')
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=2
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=2

# %%
optical_band='no_optical'
uv_band='NUV_D'
delays = [0, 2, 4, 8]
colors=['tab:blue','tab:orange','tab:green', 'tab:red']


fig, ax = plt.subplots(figsize=(10,10))
for delay, color in zip(delays, colors):
    legend_labels=[f'kilonova L, shock data, {delay}h delay',
                   f'kilonova D, shock data, {delay}h delay',
                   f'shock, kilonova L data, {delay}h delay',
                   f'shock, kilonova D data, {delay}h delay']
    fig, ax = bayesPlot(fig, ax, delay=delay, optical_band=optical_band, uv_band=uv_band, legend_labels=legend_labels, marker='o', color=color)


plt.title(f'{optical_band} band, {uv_band} band',fontsize=fontsize_bayesplot)
plt.ylabel("Bayes' factor: $\log_{10}(\mathcal{B})$",fontsize=fontsize_bayesplot)
plt.xlabel("Luminosity distance (Mpc)",fontsize=fontsize_bayesplot)
plt.yscale('symlog', linthresh=2)
ax.hlines(2,40,160,color='k')
ax.legend()

fig.tight_layout()
plt.show()
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=100 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=160 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=100 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=160 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=2
# No results available for kilonovamodel kilonova_uvboostdata dist=100 delay=2
# No results available for kilonovamodel kilonova_uvboostdata dist=160 delay=2
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=2
# No results available for kilonova_uvboostmodel kilonovadata dist=100 delay=2
# No results available for kilonova_uvboostmodel kilonovadata dist=160 delay=2
# ...

# %%
optical_bands=['no_optical','r','r']
uv_bands=['NUV_D','no_uv','NUV_D']
delay = 0
colors=['tab:blue','tab:orange','tab:green']
dists=[40, 70, 100, 130, 160]


fig, ax = plt.subplots(figsize=(10,10))
for optical_band, uv_band, color in zip(optical_bands, uv_bands, colors):
    legend_labels=[f'kilonova L, shock data, {optical_band}, {uv_band}',
                   f'kilonova D, shock data, {optical_band}, {uv_band}',
                   f'shock, kilonova L data, {optical_band}, {uv_band}',
                   f'shock, kilonova D data, {optical_band}, {uv_band}']
    fig, ax = bayesPlot(fig, ax, delay=delay, dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=legend_labels, marker='o', color=color)


plt.title(f'{delay}h delay',fontsize=fontsize_bayesplot)
plt.ylabel("Bayes' factor: $\log_{10}(\mathcal{B})$",fontsize=fontsize_bayesplot)
plt.xlabel("Luminosity distance (Mpc)",fontsize=fontsize_bayesplot)
plt.yscale('symlog', linthresh=2)
ax.hlines(2,40,160,color='k')
ax.legend()

fig.tight_layout()
plt.show()
# Out:
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=70 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=100 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=130 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=160 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=40 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=70 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=100 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=130 delay=0
# No results available for kilonova_uvboostmodel kilonovadata dist=160 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=40 delay=0
# No results available for kilonovamodel kilonova_uvboostdata dist=70 delay=0
# ...

# %% [markdown]
# # Bayes plots

# %% [markdown]
# ## horizontal

# %%
optical_band='no_optical'
uv_band='NUV_D'
band = 'UV band'
dists=[40, 70, 100, 130, 160]
kilonovamodels = ['kilonova','kilonova_uvboost']
bayesTitles = ['Default Kilonova Model', 'Lower Early Opacity Kilonova Model']
legends = [False, True]
ylabels = [True, False]

fig, axes = plt.subplots(1,2, sharey=True, figsize=(10,5))
for ax, kilonovamodel, title, legend, ylabel in zip(axes, kilonovamodels, bayesTitles, legends, ylabels):
    fig, ax = bayesPlot(fig, ax, models=['shock', kilonovamodel], datas=['shock',kilonovamodel], dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=[f'Shock data in {band}',f'Kilonova data in {band}'], marker='o', color='tab:blue')
    ax.set_title(f'{title}',fontsize=fontsize_bayesplot)
    ax.set_yscale('symlog', linthresh=2)
    ax.hlines(2,40,160,color='k',label='$\log_{10}(\mathcal{B})=2$')
    ax.set_xlabel('$d_L$ (Mpc)',fontsize=fontsize_bayesplot)
    if legend:
        ax.legend(loc='upper right')
    if ylabel:
        ax.set_ylabel('$\log_{10}(\mathcal{B})$',fontsize=fontsize_bayesplot)
        
fig.tight_layout()
plt.show()
fig.savefig(f'./plots/bayes_plot_UV.png',dpi=300)

# %%
optical_bands=['no_optical','r','r']
uv_bands=['NUV_D','no_uv','NUV_D']
bands = ['UV band', 'r band', 'UV and r band']
markers = ['o', 'P', '*']
bayesColors=['tab:orange','tab:blue','tab:green']
dists=[40, 70, 100, 130, 160]
kilonovamodels = ['kilonova','kilonova_uvboost']
bayesTitles = ['Default Kilonova Model', 'Lower Early Opacity Kilonova Model']
legends = [False, True]
ylabels = [True, False]

fig, axes = plt.subplots(1,2, sharey=True, figsize=(11.5,3.5))
for ax, kilonovamodel, title, legend, ylabel in zip(axes, kilonovamodels, bayesTitles, legends, ylabels):
    for uv_band, optical_band, band, marker, color in zip(uv_bands, optical_bands, bands, markers, bayesColors):
        fig, ax = bayesPlot(fig, ax, models=['shock', kilonovamodel], datas=['shock',kilonovamodel], dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=[f'Shock data, {band}',f'Kilonova data, {band}'], marker=marker, color=color)
    ax.set_title(f'{title}',fontsize=fontsize_bayesplot-1)
    ax.set_yscale('symlog', linthresh=2)
    ax.hlines(2,40,160,color='k',label='$\log_{10}(\mathcal{B})=2$')
    ax.tick_params(axis='x', labelsize=fontsize_bayesplot-1)
    ax.set_xlabel('$d_L$ (Mpc)',fontsize=fontsize_bayesplot-1)
    if legend:
        ax.legend(bbox_to_anchor=(1,1),loc='upper left',fontsize=fontsize_bayesplot-2)
    if ylabel:
        ax.set_ylabel('$\log_{10}(\mathcal{B})$',fontsize=fontsize_bayesplot-1)
        ax.tick_params(axis='y', labelsize=fontsize_bayesplot-1)
fig.tight_layout()
plt.show()
fig.savefig(f'./plots/bayes_plot_bands.png',dpi=300)

# %%
optical_band='no_optical'
uv_band='NUV_D'
delays = [0, 2, 4, 12]
first_datas=['1.2','3.2','5.2','13.2']
markers = ['o', 'P', '*', 'D', 'v']
bayesColors=['tab:orange','tab:blue','tab:green', 'tab:red', 'tab:purple']
dists=[40, 70, 100, 130, 160]
kilonovamodels = ['kilonova','kilonova_uvboost']
bayesTitles = ['Default Kilonova Model', 'Lower Early Opacity Kilonova Model']
legends = [False, True]
ylabels = [True, False]

fig, axes = plt.subplots(1,2, sharey=True, figsize=(11.5,3.5))
for ax, kilonovamodel, title, legend, ylabel in zip(axes, kilonovamodels, bayesTitles, legends, ylabels):
    for delay, first_data, marker, color in zip(delays, first_datas, markers, bayesColors):
        fig, ax = bayesPlot(fig, ax, models=['shock', kilonovamodel], datas=['shock',kilonovamodel], delay=delay, dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=[f'Shock data, {first_data}h',f'Kilonova data, {first_data}h'], marker=marker, color=color)
    ax.set_title(f'{title}',fontsize=fontsize_bayesplot-1)
    ax.set_yscale('symlog', linthresh=2)
    ax.hlines(2,40,160,color='k',label='$\log_{10}(\mathcal{B})=2$')
    ax.tick_params(axis='x', labelsize=fontsize_bayesplot-1)
    ax.set_xlabel('$d_L$ (Mpc)',fontsize=fontsize_bayesplot-1)
    if legend:
        ax.legend(bbox_to_anchor=(1,1),loc='upper left',fontsize=fontsize_bayesplot-2)
    if ylabel:
        ax.set_ylabel('$\log_{10}(\mathcal{B})$',fontsize=fontsize_bayesplot-1)
        ax.tick_params(axis='y', labelsize=fontsize_bayesplot-1)
fig.tight_layout()
plt.show()
fig.savefig(f'./plots/bayes_plot_delays.png',dpi=300)

# %% [markdown]
# ## Vertical

# %%
optical_bands=['no_optical','r','r']
uv_bands=['NUV_D','no_uv','NUV_D']
bands = ['UV band', 'r band', 'UV and r band']
markers = ['o', '*', 'P']
bayesColors=['tab:orange','tab:blue','tab:green']
dists=[40, 70, 100, 130, 160]
kilonovamodels = ['kilonova','kilonova_uvboost']
bayesTitles = ['Default Kilonova Model', 'Lower Early Opacity Kilonova Model']
legends = [False, True]
xlabels = [False, True]

fig, axes = plt.subplots(2,1, sharex=True, sharey=True, figsize=(5,8))
for ax, kilonovamodel, title, legend, xlabel in zip(axes, kilonovamodels, bayesTitles, legends, xlabels):
    for uv_band, optical_band, band, marker, color in zip(uv_bands, optical_bands, bands, markers, bayesColors):
        fig, ax = bayesPlot(fig, ax, models=['shock', kilonovamodel], datas=['shock',kilonovamodel], dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=[f'Shock data in {band}',f'Kilonova data in {band}'], marker=marker, color=color)
    ax.set_title(f'{title}',fontsize=fontsize_bayesplot)
    ax.set_yscale('symlog', linthresh=2)
    ax.hlines(2,40,160,color='k',label='$\log_{10}(\mathcal{B})=2$')
    ax.set_ylabel('$\log_{10}(\mathcal{B})$',fontsize=fontsize_bayesplot)
    if legend:
        ax.legend(loc='upper right')
    if xlabel:
        ax.set_xlabel('$d_L$ (Mpc)',fontsize=fontsize_bayesplot)

fig.tight_layout()
plt.show()
fig.savefig(f'./plots/bayes_plot_bands.png',dpi=300)

# %%
fontsize_bayesplot=15
optical_band='no_optical'
uv_band='NUV_D'
delays = [0, 2, 4, 8]
first_datas=['1.2','3.2','5.2','9.2']
markers = ['o', '*', 'P', 'D']
bayesColors=['tab:orange','tab:blue','tab:green', 'tab:red']
dists=[40, 70, 100, 130, 160]
kilonovamodels = ['kilonova','kilonova_uvboost']
bayesTitles = ['Default Kilonova Model', 'Lower Early Opacity Kilonova Model']
legends = [False, True]
xlabels = [False, True]

fig, axes = plt.subplots(2,1, sharex=True, sharey=True, figsize=(5,8))
for ax, kilonovamodel, title, legend, xlabel in zip(axes, kilonovamodels, bayesTitles, legends, xlabels):
    for delay, first_data, marker, color in zip(delays, first_datas, markers, bayesColors):
        fig, ax = bayesPlot(fig, ax, models=['shock', kilonovamodel], datas=['shock',kilonovamodel], delay=delay, dists=dists, optical_band=optical_band, uv_band=uv_band, legend_labels=[f'Shock data starts at {first_data}h',f'Kilonova data starts at {first_data}h'], marker=marker, color=color)
    ax.set_title(f'{title}',fontsize=fontsize_bayesplot)
    ax.set_yscale('symlog', linthresh=2)
    ax.hlines(2,40,160,color='k',label='$\log_{10}(\mathcal{B})=2$')
    ax.set_ylabel('$\log_{10}(\mathcal{B})$',fontsize=fontsize_bayesplot)
    if legend:
        ax.legend(loc='upper right')
    if xlabel:
        ax.set_xlabel('$d_L$ (Mpc)',fontsize=fontsize_bayesplot)
    
fig.tight_layout()
plt.show()
fig.savefig(f'./plots/bayes_plot_delays.png',dpi=300)
